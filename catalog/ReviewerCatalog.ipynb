# %% [markdown]
# # ReviewerCatalog

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Registry

# %%
from ReviewerCatalog import display_catalog_df

# %%
display_catalog_df()
# Out:
# <style type="text/css">
# #T_fd7f9 th {
#   vertical-align: top;
# }
# #T_fd7f9 .row0 {
#   border-top: 1px solid black;
# }
# #T_fd7f9 .row15 {
#   border-top: 1px solid black;
# }
# #T_fd7f9 .row13 {
#   border-top: 1px solid black;
# }
# #T_fd7f9 .row23 {
#   border-top: 1px solid black;
# }
# #T_fd7f9 .row7 {
#   border-top: 1px solid black;
# }
# ...

# %% [markdown]
# # Add a Reviewer Suite to Catalog
#
#
# 1. Set up repo
#     Registered repos must satisfy the following:
#     - Public
#     - Has a description
#     - Structured like so (see [AnnoMateTemplate](https://github.com/getzlab/AnnoMateTemplate))
#         ```
#         MyReviewers/
#             MyReviewers/
#                 Reviewers/
#                     Reviewer1.py
#                     Reviewer2.py
#                     ...
#                 AppComponents/
#                     AppComponent1.py
#                     AppComponent2.py
#                     ...
#         ```
#    - `setup.py` file
#
# 1. Fork AnnoMate and go to `example_notebooks/ReviewerCatalog.py`
#     1. Add the github url of your reviewer repo to the variable `registered_reviewer_repos`
#     1. Go to `example_notebooks/ReviewerRegistry.ipynb` and run `gen_reviewer_catalog()` (below)
#     1. Check `catalog.tsv`
#
# 1. Commit and submit a pull request

# %%
from ReviewerCatalog import gen_reviewer_catalog, registered_reviewer_repos

# %%
gen_reviewer_catalog()
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:04<00:00,  1.21it/s]

# %% [markdown]
# # Create a reviewer suite
#
# See [Developer_AnnoMate_Tutorial.ipynb](https://github.com/getzlab/AnnoMate/blob/master/example_notebooks/Developer_AnnoMate_Tutorial.ipynb) for instructions on how to create a reviewer.
